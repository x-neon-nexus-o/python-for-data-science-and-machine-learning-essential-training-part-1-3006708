# %% [markdown]
# ## Python requests for automating data collection.

# %%
import requests

# %%
response = requests.get("https://www.python.org")
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Headers

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '11350', 'x-frame-options': 'SAMEORIGIN', 'via': '1.1 varnish, 1.1 varnish, 1.1 varnish', 'content-type': 'text/html; charset=utf-8', 'content-encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Date': 'Sun, 14 Dec 2025 06:04:02 GMT', 'Age': '2918', 'X-Served-By': 'cache-iad-kiad7000022-IAD, cache-iad-kiad7000081-IAD, cache-bom-vanm7210076-BOM', 'X-Cache': 'MISS, HIT, HIT', 'X-Cache-Hits': '0, 324, 121', 'X-Timer': 'S1765692242.481522,VS0,VE0', 'Vary': 'Cookie', 'Strict-Transport-Security': 'max-age=63072000; includeSubDomains; preload'}

# %% [markdown]
# ### Content Types

# %%
response.headers["Content-Type"]
# Out:
# 'text/html; charset=utf-8'

# %% [markdown]
# ### Body/Content
